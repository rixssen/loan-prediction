# %%
import pandas as pd

# %%
df = pd.read_csv("ml2.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001003    Male     Yes          1      Graduate            No
# 1    LP001005    Male     Yes          0      Graduate           Yes
# 2    LP001006    Male     Yes          0  Not Graduate            No
# 3    LP001008    Male      No          0      Graduate            No
# 4    LP001013    Male     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 376  LP002953    Male     Yes         3+      Graduate            No
# 377  LP002974    Male     Yes          0      Graduate            No
# 378  LP002978  Female      No          0      Graduate            No
# 379  LP002979    Male     Yes         3+      Graduate            No
# 380  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender                5
# Married               0
# Dependents            8
# Education             0
# Self_Employed        21
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     11
# Credit_History       30
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df["Loan_Status"].value_counts()
# Out:
# Loan_Status
# Y    271
# N    110
# Name: count, dtype: int64

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001003    Male     Yes          1      Graduate            No
# 1    LP001005    Male     Yes          0      Graduate           Yes
# 2    LP001006    Male     Yes          0  Not Graduate            No
# 3    LP001008    Male      No          0      Graduate            No
# 4    LP001013    Male     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 376  LP002953    Male     Yes         3+      Graduate            No
# 377  LP002974    Male     Yes          0      Graduate            No
# 378  LP002978  Female      No          0      Graduate            No
# 379  LP002979    Male     Yes         3+      Graduate            No
# 380  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            381 non-null    object
#  1   Gender             376 non-null    object
#  2   Married            381 non-null    object
#  3   Dependents         373 non-null    object
#  4   Education          381 non-null    object
#  5   Self_Employed      360 non-null    object
#  6   ApplicantIncome    381 non-null    int64
#  7   CoapplicantIncome  381 non-null    float64
#  8   LoanAmount         381 non-null    float64
#  9   Loan_Amount_Term   370 non-null    float64
#  10  Credit_History     351 non-null    float64
#  11  Property_Area      381 non-null    object
#  12  Loan_Status        381 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 38.8+ KB

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001003    Male     Yes          1      Graduate            No
# 1    LP001005    Male     Yes          0      Graduate           Yes
# 2    LP001006    Male     Yes          0  Not Graduate            No
# 3    LP001008    Male      No          0      Graduate            No
# 4    LP001013    Male     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 376  LP002953    Male     Yes         3+      Graduate            No
# 377  LP002974    Male     Yes          0      Graduate            No
# 378  LP002978  Female      No          0      Graduate            No
# 379  LP002979    Male     Yes         3+      Graduate            No
# 380  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
cat1 = df.select_dtypes(include  = "object")

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender                5
# Married               0
# Dependents            8
# Education             0
# Self_Employed        21
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     11
# Credit_History       30
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df = df.dropna()

# %%
cat1.isna().sum()
# Out:
# Loan_ID           0
# Gender            5
# Married           0
# Dependents        8
# Education         0
# Self_Employed    21
# Property_Area     0
# Loan_Status       0
# dtype: int64

# %%
cat1.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      245
# Female     63
# Name: count, dtype: int64

# %%
cat1 = cat1.drop(columns = ["Loan_ID"])

# %%
cat1
# Out:
#      Gender Married Dependents     Education Self_Employed Property_Area  \
# 0      Male     Yes          1      Graduate            No         Rural
# 1      Male     Yes          0      Graduate           Yes         Urban
# 2      Male     Yes          0  Not Graduate            No         Urban
# 3      Male      No          0      Graduate            No         Urban
# 4      Male     Yes          0  Not Graduate            No         Urban
# ..      ...     ...        ...           ...           ...           ...
# 376    Male     Yes         3+      Graduate            No         Urban
# 377    Male     Yes          0      Graduate            No         Rural
# 378  Female      No          0      Graduate            No         Rural
# 379    Male     Yes         3+      Graduate            No         Rural
# 380  Female      No          0      Graduate           Yes     Semiurban
#
#     Loan_Status
# 0             N
# 1             Y
# 2             Y
# 3             Y
# ...

# %%
for i in cat1:
    print(f"value counts {i.value_counts()}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 for i in cat1:
# ----> 2     print(f"value counts {i.value_counts()}")
#
# AttributeError: 'str' object has no attribute 'value_counts'

# %%
for i in cat1:
    print(f"\n--- Value counts for {i} ---")
    print(cat1[i].value_counts(dropna=False))
# Out:
# --- Value counts for Gender ---
# Gender
# Male      291
# Female     85
# NaN         5
# Name: count, dtype: int64
#
# --- Value counts for Married ---
# Married
# Yes    228
# No     153
# Name: count, dtype: int64
#
# --- Value counts for Dependents ---
# Dependents
# 0      234
# 2       59
# 1       52
# 3+      28
# NaN      8
# Name: count, dtype: int64
#
# --- Value counts for Education ---
# Education
# Graduate        278
# Not Graduate    103
# Name: count, dtype: int64
#
# --- Value counts for Self_Employed ---
# Self_Employed
# No     325
# Yes     35
# NaN     21
# Name: count, dtype: int64
#
# --- Value counts for Property_Area ---
# Property_Area
# Semiurban    149
# Urban        126
# Rural        106
# Name: count, dtype: int64
#
# --- Value counts for Loan_Status ---
# Loan_Status
# Y    271
# N    110
# Name: count, dtype: int64

# %%
num = df.select_dtypes(include = "number")

# %%
num.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 num.describe()
#
# NameError: name 'num' is not defined

# %%
cat1["Gender"]
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 376      Male
# 377      Male
# 378    Female
# 379      Male
# 380    Female
# Name: Gender, Length: 381, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
for i in cat1:
    print(e.fit_transform(cat1[i])
# Out:
#   Cell In[25], line 3
#
#     ^
# SyntaxError: incomplete input

# %%
cat = cat1[["Gender" , "Married" , "Education" "Self_Employed" "Loan_Status"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 cat = cat1[["Gender" , "Married" , "Education" "Self_Employed" "Loan_Status"]]
#
# File ~/Documents/customer churn/.conda/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documents/customer churn/.conda/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
cat1.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
cat = cat1[["Gender" , "Married" , "Education" , "Self_Employed" , "Loan_Status"]]

# %%
for i in cat1:
    cat1[i]=(le.fit_transform(cat1[i]))

# %%
cat1.corr()["Loan_Status"]
# Out:
# Gender           0.085155
# Married          0.123695
# Dependents       0.031610
# Education       -0.052029
# Self_Employed   -0.047567
# Property_Area    0.034770
# Loan_Status      1.000000
# Name: Loan_Status, dtype: float64

# %%
cat1.corr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cat1.corr
#
# NameError: name 'cat1' is not defined

# %%
import seaborn as sns

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
sns.heatmap(cat1.corr_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 sns.heatmap(cat1.corr_)
#
# NameError: name 'sns' is not defined

# %%
cat1
# Out:
#      Gender Married Dependents     Education Self_Employed Property_Area  \
# 0      Male     Yes          1      Graduate            No         Rural
# 1      Male     Yes          0      Graduate           Yes         Urban
# 2      Male     Yes          0  Not Graduate            No         Urban
# 3      Male      No          0      Graduate            No         Urban
# 4      Male     Yes          0  Not Graduate            No         Urban
# ..      ...     ...        ...           ...           ...           ...
# 376    Male     Yes         3+      Graduate            No         Urban
# 377    Male     Yes          0      Graduate            No         Rural
# 378  Female      No          0      Graduate            No         Rural
# 379    Male     Yes         3+      Graduate            No         Rural
# 380  Female      No          0      Graduate           Yes     Semiurban
#
#     Loan_Status
# 0             N
# 1             Y
# 2             Y
# 3             Y
# ...

# %%
for i in cat1.columns:
    cat1[i] = le.fit_transform(cat1[i])

# %%
cat1
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Property_Area  \
# 0         1        1           1          0              0              0
# 1         1        1           0          0              1              2
# 2         1        1           0          1              0              2
# 3         1        0           0          0              0              2
# 4         1        1           0          1              0              2
# ..      ...      ...         ...        ...            ...            ...
# 376       1        1           3          0              0              2
# 377       1        1           0          0              0              0
# 378       0        0           0          0              0              0
# 379       1        1           3          0              0              0
# 380       0        0           0          0              1              1
#
#      Loan_Status
# 0              0
# 1              1
# 2              1
# ...

# %%
cat1
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Property_Area  \
# 0         1        1           1          0              0              0
# 1         1        1           0          0              1              2
# 2         1        1           0          1              0              2
# 3         1        0           0          0              0              2
# 4         1        1           0          1              0              2
# ..      ...      ...         ...        ...            ...            ...
# 376       1        1           3          0              0              2
# 377       1        1           0          0              0              0
# 378       0        0           0          0              0              0
# 379       1        1           3          0              0              0
# 380       0        0           0          0              1              1
#
#      Loan_Status
# 0              0
# 1              1
# 2              1
# ...

# %%
cat1.corr()
# Out:
#                  Gender   Married  Dependents  Education  Self_Employed  \
# Gender         1.000000  0.340476    0.186934   0.102832      -0.067022
# Married        0.340476  1.000000    0.337954   0.040532      -0.031636
# Dependents     0.186934  0.337954    1.000000   0.122889       0.051720
# Education      0.102832  0.040532    0.122889   1.000000       0.002084
# Self_Employed -0.067022 -0.031636    0.051720   0.002084       1.000000
# Property_Area  0.001534  0.034601    0.064862  -0.086582      -0.071441
# Loan_Status   -0.014497  0.092473   -0.023511  -0.055586       0.035915
#
#                Property_Area  Loan_Status
# Gender              0.001534    -0.014497
# Married             0.034601     0.092473
# Dependents          0.064862    -0.023511
# Education          -0.086582    -0.055586
# Self_Employed      -0.071441     0.035915
# Property_Area       1.000000     0.057834
# Loan_Status         0.057834     1.000000

# %%
df.select_dtypes(include = 'number').corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.243677    0.267628
# CoapplicantIncome        -0.243677           1.000000    0.123028
# LoanAmount                0.267628           0.123028    1.000000
# Loan_Amount_Term         -0.099571          -0.004158    0.135069
# Credit_History            0.030307           0.012715   -0.043853
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.099571        0.030307
# CoapplicantIncome         -0.004158        0.012715
# LoanAmount                 0.135069       -0.043853
# Loan_Amount_Term           1.000000        0.015269
# Credit_History             0.015269        1.000000

# %%
x = df[""]

# %%
df.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data = df[["Married" , "Dependents" , "LoanAmount" , "ApplicantIncome" , "CoapplicantIncome" , "Loan_Amount_Term" ,"Loan_Status" ]]

# %%
lr = LabelEncoder()

# %%
data["Loan_Status"]=lr.fit_transform(data["Loan_Status"])
# Out:
# /var/folders/4g/yywmsp6n68d_30vybd7vkr100000gn/T/ipykernel_83532/828278217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Loan_Status"]=lr.fit_transform(data["Loan_Status"])

# %%
data.dtypes
# Out:
# Married               object
# Dependents            object
# LoanAmount           float64
# ApplicantIncome        int64
# CoapplicantIncome    float64
# Loan_Amount_Term     float64
# Loan_Status            int64
# dtype: object

# %%
data["Dependents"] = data["Dependents"].replace( "3+",3).astype(int)
# Out:
# /var/folders/4g/yywmsp6n68d_30vybd7vkr100000gn/T/ipykernel_83532/372314204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Dependents"] = data["Dependents"].replace( "3+",3).astype(int)

# %%
data1 = data[["Married", "Loan_Status"]].copy()

# %%
for i in data1:
    data1[i]=(lr.fit_transform(data1[i]))

# %%
data1
# Out:
#      Married  Loan_Status
# 0          1            0
# 1          1            1
# 2          1            1
# 3          0            1
# 4          1            1
# ..       ...          ...
# 376        1            1
# 377        1            1
# 378        0            1
# 379        1            1
# 380        0            0
#
# [308 rows x 2 columns]

# %%
data.update(data1)

# %%
data[data.select_dtypes(include = float).columns] = data.select_dtypes(include = float).astype(int)
# Out:
# /var/folders/4g/yywmsp6n68d_30vybd7vkr100000gn/T/ipykernel_83532/2789032998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[data.select_dtypes(include = float).columns] = data.select_dtypes(include = float).astype(int)

# %%
data["Married"] = data["Married"].astype(int)
# Out:
# /var/folders/4g/yywmsp6n68d_30vybd7vkr100000gn/T/ipykernel_83532/3603693032.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Married"] = data["Married"].astype(int)

# %%
data.dtypes
# Out:
# Married              int64
# Dependents           int64
# LoanAmount           int64
# ApplicantIncome      int64
# CoapplicantIncome    int64
# Loan_Amount_Term     int64
# Loan_Status          int64
# dtype: object

# %%
x = data.drop(columns= "Loan_Status")
y = data["Loan_Status"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , Y_train , y_test = train_test_split(x,y , test_size= 0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
model = lr.fit(x_train , Y_train)

# %%
from sklearn.metrics import accuracy_score , confusion_matrix , classification_report

# %%
accuracy_score(y_test , y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 accuracy_score(y_test , y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sr = StandardScaler()

# %%
x_newtrain = sr.fit_transform(x_train)
x_newtest = sr.transform(x_test)

# %%
model1= lr.fit(x_newtrain , Y_train)

# %%
y_pred = model1.predict(x_newtest)

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.6774193548387096

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Example usage (Classifier)
# clf = DecisionTreeClassifier(random_state=42)
# clf.fit(X_train, y_train)

# %%
model2 = DecisionTreeClassifier()
model3= RandomForestClassifier()

# %%
model2.fit(x_train , Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model2.predict(x_test)

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.5483870967741935

# %%
model3.fit(x_train ,Y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model3.predict(x_test)

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.7419354838709677

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier

# %%
model4 = XGBClassifier(n_estimators=200,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    use_label_encoder=False,
    eval_metric='logloss')

# %%
model4.fit(x_train , Y_train)
# Out:
# [15:13:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = model4.predict(x_test)

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.6612903225806451

# %%
final = RandomForestClassifier()

# %%
final.fit(x_train , Y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred =final.predict(x_test)

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.7096774193548387

# %%
import joblib
joblib.dump(final,"final.pkl")
# Out:
# ['final.pkl']
